# %%
# %pip install llama-index
# %pip install llama-index-readers-web
# %pip install langchain
# %pip install llama-index-llms-ollama
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.core import KeywordTableIndex, SimpleDirectoryReader

# alternatively
from llama_index.llms.ollama import Ollama

# %% [raw]
# documents = SimpleDirectoryReader("data").load_data()
# # define LLM
# #llm = Ollama()
# llm = Ollama(model="llama2:7b-chat", request_timeout=30.0, base_url="http://ollama-mchomaredhatcom.apps.ai-hackathon.qic7.p1.openshiftapps.com:80")
# #llm = Ollama(model="mistral", request_timeout=30.0, base_url="http://localhost:11434")
# # build index
# index = KeywordTableIndex.from_documents(documents, llm=llm)
